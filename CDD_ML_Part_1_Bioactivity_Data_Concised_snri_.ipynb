# %% [markdown]
# <a href="https://colab.research.google.com/github/smruti1571/Python/blob/main/CDD_ML_Part_1_Bioactivity_Data_Concised_snri_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Smruti Rekha Behera
#
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.8/dist-packages (0.10.8)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (2.25.1)
# Requirement already satisfied: requests-cache~=0.7.0 in /usr/local/lib/python3.8/dist-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.12.7)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.8/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.8/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.8/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.8/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for SNRI**

# %%
# Target search for depression
target = new_client.target
target_query = target.search('serotonin')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references           organism  \
# 0   [{'xref_id': 'Q29495', 'xref_name': None, 'xre...         Ovis aries
# 1   [{'xref_id': 'Q64666', 'xref_name': None, 'xre...  Rattus norvegicus
# 2   [{'xref_id': 'P31645', 'xref_name': None, 'xre...       Homo sapiens
# 3   [{'xref_id': 'P31652', 'xref_name': None, 'xre...  Rattus norvegicus
# 4   [{'xref_id': 'NBK23655', 'xref_name': 'Seroton...       Mus musculus
# ..                                                ...                ...
# 90                                                 []       Mus musculus
# 91  [{'xref_id': 'P08909', 'xref_name': None, 'xre...  Rattus norvegicus
# 92                                                 []       Homo sapiens
# 93                                                 []       Homo sapiens
# 94                                                 []  Rattus norvegicus
#
#                                             pref_name  score  \
# 0                       Serotonin N-acetyltransferase   13.0
# 1                       Serotonin N-acetyltransferase   13.0
# 2                               Serotonin transporter   12.0
# 3                               Serotonin transporter   12.0
# 4                               Serotonin transporter   12.0
# ..                                                ...    ...
# 90                     Serotonin 2c (5-HT2c) receptor    7.0
# 91                     Serotonin 2c (5-HT2c) receptor    7.0
# 92     Dopamine D2 receptor and serotonin 1a receptor    7.0
# 93                              Monoamine transporter    7.0
# 94  Serotonin 1a (5-HT1a) receptor/Adrenergic rece...    5.0
#
#     species_group_flag target_chembl_id  \
# 0                False       CHEMBL5452
# 1                False    CHEMBL1075242
# 2                False        CHEMBL228
# 3                False        CHEMBL313
# 4                False       CHEMBL4642
# ..                 ...              ...
# 90               False       CHEMBL3006
# 91               False        CHEMBL324
# 92               False    CHEMBL2111460
# 93               False    CHEMBL2363064
# 94               False    CHEMBL2097171
#
#                                     target_components        target_type  \
# 0   [{'accession': 'Q29495', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'Q64666', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'P31645', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P31652', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'Q60857', 'component_descriptio...     SINGLE PROTEIN
# ..                                                ...                ...
# 90  [{'accession': 'P34968', 'component_descriptio...     SINGLE PROTEIN
# 91  [{'accession': 'P08909', 'component_descriptio...     SINGLE PROTEIN
# 92  [{'accession': 'P14416', 'component_descriptio...  SELECTIVITY GROUP
# 93  [{'accession': 'P31645', 'component_descriptio...     PROTEIN FAMILY
# 94  [{'accession': 'P15823', 'component_descriptio...  SELECTIVITY GROUP
#
#     tax_id
# 0     9940
# 1    10116
# 2     9606
# 3    10116
# 4    10090
# ..     ...
# 90   10090
# 91   10116
# 92    9606
# 93    9606
# 94   10116
#
# [95 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human SNRI*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL228'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human SNRI* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(10)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None       105351                  []    CHEMBL806861
# 1             None       105826                  []    CHEMBL808141
# 2             None       106988                  []    CHEMBL873260
# 3             None       108742                  []    CHEMBL806861
# 4             None       111537                  []    CHEMBL806861
# 5             None       112956                  []    CHEMBL806861
# 6             None       118016                  []    CHEMBL806861
# 7             None       122882                  []    CHEMBL806861
# 8             None       122884                  []    CHEMBL806861
# 9             None       124744                  []    CHEMBL808141
#
#                                    assay_description assay_type  \
# 0  Inhibition of [3H]citalopram binding to seroto...          B
# 1  Binding affinity towards serotonin transporter...          B
# 2  Binding affinity towards serotonin transporter...          B
# 3  Inhibition of [3H]citalopram binding to seroto...          B
# 4  Inhibition of [3H]citalopram binding to seroto...          B
# 5  Inhibition of [3H]citalopram binding to seroto...          B
# 6  Inhibition of [3H]citalopram binding to seroto...          B
# 7  Inhibition of [3H]citalopram binding to seroto...          B
# 8  Inhibition of [3H]citalopram binding to seroto...          B
# 9  Binding affinity towards serotonin transporter...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000221
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
# 3                    None                   None  BAO_0000190  BAO_0000221
# 4                    None                   None  BAO_0000190  BAO_0000221
# 5                    None                   None  BAO_0000190  BAO_0000221
# 6                    None                   None  BAO_0000190  BAO_0000221
# 7                    None                   None  BAO_0000190  BAO_0000221
# 8                    None                   None  BAO_0000190  BAO_0000221
# 9                    None                   None  BAO_0000190  BAO_0000357
#
#    ... target_organism       target_pref_name target_tax_id text_value  toid  \
# 0  ...    Homo sapiens  Serotonin transporter          9606       None  None
# 1  ...    Homo sapiens  Serotonin transporter          9606       None  None
# 2  ...    Homo sapiens  Serotonin transporter          9606       None  None
# 3  ...    Homo sapiens  Serotonin transporter          9606       None  None
# 4  ...    Homo sapiens  Serotonin transporter          9606       None  None
# 5  ...    Homo sapiens  Serotonin transporter          9606       None  None
# 6  ...    Homo sapiens  Serotonin transporter          9606       None  None
# 7  ...    Homo sapiens  Serotonin transporter          9606       None  None
# 8  ...    Homo sapiens  Serotonin transporter          9606       None  None
# 9  ...    Homo sapiens  Serotonin transporter          9606       None  None
#
#    type  units    uo_units upper_value   value
# 0  IC50     nM  UO_0000065        None  5160.0
# 1  IC50     nM  UO_0000065        None    1.15
# 2  IC50     nM  UO_0000065        None     4.2
# 3  IC50     nM  UO_0000065        None    33.4
# 4  IC50     nM  UO_0000065        None    27.6
# 5  IC50     nM  UO_0000065        None     6.5
# 6  IC50     nM  UO_0000065        None   180.0
# 7  IC50     nM  UO_0000065        None  1960.0
# 8  IC50     nM  UO_0000065        None     2.5
# 9  IC50     nM  UO_0000065        None    0.32
#
# [10 rows x 45 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('serotonin_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-72-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#      activity_comment  activity_id  \
# 0                None       105351
# 1                None       105826
# 2                None       106988
# 3                None       108742
# 4                None       111537
# ...               ...          ...
# 4462             None     23305408
# 4463             None     23305409
# 4464             None     23305410
# 4465           Active     23349824
# 4466             None     23353728
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL806861
# 1                                                    []    CHEMBL808141
# 2                                                    []    CHEMBL873260
# 3                                                    []    CHEMBL806861
# 4                                                    []    CHEMBL806861
# ...                                                 ...             ...
# 4462  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4842938
# 4463  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4842938
# 4464  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4842938
# 4465                                                 []   CHEMBL4882629
# 4466                                                 []   CHEMBL4883048
#
#                                       assay_description assay_type  \
# 0     Inhibition of [3H]citalopram binding to seroto...          B
# 1     Binding affinity towards serotonin transporter...          B
# 2     Binding affinity towards serotonin transporter...          B
# 3     Inhibition of [3H]citalopram binding to seroto...          B
# 4     Inhibition of [3H]citalopram binding to seroto...          B
# ...                                                 ...        ...
# 4462  Inhibition of human wild type SERT expressed i...          B
# 4463  Inhibition of human wild type SERT expressed i...          B
# 4464  Inhibition of human wild type SERT expressed i...          B
# 4465                             Serotonin-uptake assay          B
# 4466  Transporter, Serotonin (5- Hydroxytryptamine) ...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000221
# 1                       None                   None  BAO_0000190  BAO_0000357
# 2                       None                   None  BAO_0000190  BAO_0000357
# 3                       None                   None  BAO_0000190  BAO_0000221
# 4                       None                   None  BAO_0000190  BAO_0000221
# ...                      ...                    ...          ...          ...
# 4462                    None                   None  BAO_0000190  BAO_0000219
# 4463                    None                   None  BAO_0000190  BAO_0000219
# 4464                    None                   None  BAO_0000190  BAO_0000219
# 4465                    None                   None  BAO_0000190  BAO_0000357
# 4466                    None                   None  BAO_0000190  BAO_0000357
#
#       ... target_organism       target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Serotonin transporter          9606       None
# 1     ...    Homo sapiens  Serotonin transporter          9606       None
# 2     ...    Homo sapiens  Serotonin transporter          9606       None
# 3     ...    Homo sapiens  Serotonin transporter          9606       None
# 4     ...    Homo sapiens  Serotonin transporter          9606       None
# ...   ...             ...                    ...           ...        ...
# 4462  ...    Homo sapiens  Serotonin transporter          9606       None
# 4463  ...    Homo sapiens  Serotonin transporter          9606       None
# 4464  ...    Homo sapiens  Serotonin transporter          9606       None
# 4465  ...    Homo sapiens  Serotonin transporter          9606       None
# 4466  ...    Homo sapiens  Serotonin transporter          9606       None
#
#       toid  type  units    uo_units upper_value   value
# 0     None  IC50     nM  UO_0000065        None  5160.0
# 1     None  IC50     nM  UO_0000065        None    1.15
# 2     None  IC50     nM  UO_0000065        None     4.2
# 3     None  IC50     nM  UO_0000065        None    33.4
# 4     None  IC50     nM  UO_0000065        None    27.6
# ...    ...   ...    ...         ...         ...     ...
# 4462  None  IC50     nM  UO_0000065        None    43.0
# 4463  None  IC50     nM  UO_0000065        None   135.0
# 4464  None  IC50     nM  UO_0000065        None   881.0
# 4465  None  IC50     nM  UO_0000065        None    13.0
# 4466  None  IC50     µM        None        None    9.47
#
# [3500 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 3001

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  \
# 0                None       105351
# 1                None       105826
# 2                None       106988
# 3                None       108742
# 4                None       111537
# ...               ...          ...
# 4461             None     23305407
# 4462             None     23305408
# 4463             None     23305409
# 4464             None     23305410
# 4466             None     23353728
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL806861
# 1                                                    []    CHEMBL808141
# 2                                                    []    CHEMBL873260
# 3                                                    []    CHEMBL806861
# 4                                                    []    CHEMBL806861
# ...                                                 ...             ...
# 4461  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4842938
# 4462  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4842938
# 4463  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4842938
# 4464  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4842938
# 4466                                                 []   CHEMBL4883048
#
#                                       assay_description assay_type  \
# 0     Inhibition of [3H]citalopram binding to seroto...          B
# 1     Binding affinity towards serotonin transporter...          B
# 2     Binding affinity towards serotonin transporter...          B
# 3     Inhibition of [3H]citalopram binding to seroto...          B
# 4     Inhibition of [3H]citalopram binding to seroto...          B
# ...                                                 ...        ...
# 4461  Inhibition of human wild type SERT expressed i...          B
# 4462  Inhibition of human wild type SERT expressed i...          B
# 4463  Inhibition of human wild type SERT expressed i...          B
# 4464  Inhibition of human wild type SERT expressed i...          B
# 4466  Transporter, Serotonin (5- Hydroxytryptamine) ...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000221
# 1                       None                   None  BAO_0000190  BAO_0000357
# 2                       None                   None  BAO_0000190  BAO_0000357
# 3                       None                   None  BAO_0000190  BAO_0000221
# 4                       None                   None  BAO_0000190  BAO_0000221
# ...                      ...                    ...          ...          ...
# 4461                    None                   None  BAO_0000190  BAO_0000219
# 4462                    None                   None  BAO_0000190  BAO_0000219
# 4463                    None                   None  BAO_0000190  BAO_0000219
# 4464                    None                   None  BAO_0000190  BAO_0000219
# 4466                    None                   None  BAO_0000190  BAO_0000357
#
#       ... target_organism       target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Serotonin transporter          9606       None
# 1     ...    Homo sapiens  Serotonin transporter          9606       None
# 2     ...    Homo sapiens  Serotonin transporter          9606       None
# 3     ...    Homo sapiens  Serotonin transporter          9606       None
# 4     ...    Homo sapiens  Serotonin transporter          9606       None
# ...   ...             ...                    ...           ...        ...
# 4461  ...    Homo sapiens  Serotonin transporter          9606       None
# 4462  ...    Homo sapiens  Serotonin transporter          9606       None
# 4463  ...    Homo sapiens  Serotonin transporter          9606       None
# 4464  ...    Homo sapiens  Serotonin transporter          9606       None
# 4466  ...    Homo sapiens  Serotonin transporter          9606       None
#
#       toid  type  units    uo_units upper_value   value
# 0     None  IC50     nM  UO_0000065        None  5160.0
# 1     None  IC50     nM  UO_0000065        None    1.15
# 2     None  IC50     nM  UO_0000065        None     4.2
# 3     None  IC50     nM  UO_0000065        None    33.4
# 4     None  IC50     nM  UO_0000065        None    27.6
# ...    ...   ...    ...         ...         ...     ...
# 4461  None  IC50     nM  UO_0000065        None    15.0
# 4462  None  IC50     nM  UO_0000065        None    43.0
# 4463  None  IC50     nM  UO_0000065        None   135.0
# 4464  None  IC50     nM  UO_0000065        None   881.0
# 4466  None  IC50     µM        None        None    9.47
#
# [3001 rows x 45 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL322923             COC(=O)C1=C(c2ccc(Cl)c(Cl)c2)CC2CCC1C2
# 1          CHEMBL435341     C/C=C\c1ccc([C@H]2CC3CCC([C@H]2C(=O)OC)N3C)cc1
# 2          CHEMBL311347    COC(=O)[C@@H]1C2CC[C@H](C[C@@H]1c1ccc(I)cc1)N2C
# 3          CHEMBL100941              COC(=O)C1C2CCC(C2)CC1c1ccc(Cl)c(Cl)c1
# 4           CHEMBL87031             COC(=O)C1C(c2ccc(Cl)c(Cl)c2)CC2CCC1N2C
# ...                 ...                                                ...
# 4461      CHEMBL4857489                     COC(=O)C1CCC2CC(O)C1N2c1ccccc1
# 4462      CHEMBL4847426                        Clc1ccc(OC2CC3CCC(C2)N3)cc1
# 4463      CHEMBL4851558                        Clc1cccc(OC2CC3CCC(C2)N3)c1
# 4464      CHEMBL4873377                          Clc1ccccc1OC1CC2CCC(C1)N2
# 4466      CHEMBL1800685  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...
#
#      standard_value
# 0            5160.0
# 1              1.15
# 2               4.2
# 3              33.4
# 4              27.6
# ...             ...
# 4461           15.0
# 4462           43.0
# 4463          135.0
# 4464          881.0
# 4466           9.47
#
# [3001 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('serotonin_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('serotonin_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL322923             COC(=O)C1=C(c2ccc(Cl)c(Cl)c2)CC2CCC1C2
# 1          CHEMBL435341     C/C=C\c1ccc([C@H]2CC3CCC([C@H]2C(=O)OC)N3C)cc1
# 2          CHEMBL311347    COC(=O)[C@@H]1C2CC[C@H](C[C@@H]1c1ccc(I)cc1)N2C
# 3          CHEMBL100941              COC(=O)C1C2CCC(C2)CC1c1ccc(Cl)c(Cl)c1
# 4           CHEMBL87031             COC(=O)C1C(c2ccc(Cl)c(Cl)c2)CC2CCC1N2C
# ...                 ...                                                ...
# 2996      CHEMBL4857489                     COC(=O)C1CCC2CC(O)C1N2c1ccccc1
# 2997      CHEMBL4847426                        Clc1ccc(OC2CC3CCC(C2)N3)cc1
# 2998      CHEMBL4851558                        Clc1cccc(OC2CC3CCC(C2)N3)c1
# 2999      CHEMBL4873377                          Clc1ccccc1OC1CC2CCC(C1)N2
# 3000      CHEMBL1800685  O=C(O)c1cc(-c2ccc(C3CCNCC3)cc2)c2ccc(-c3ccc(C(...
#
#       standard_value         class
# 0            5160.00  intermediate
# 1               1.15        active
# 2               4.20        active
# 3              33.40        active
# 4              27.60        active
# ...              ...           ...
# 2996           15.00        active
# 2997           43.00        active
# 2998          135.00        active
# 2999          881.00        active
# 3000            9.47        active
#
# [3001 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('serotonin_03_bioactivity_data_curated.csv', index=False)

# %%
! zip serotonin.zip *.csv
# Out:
# updating: serotonin_01_bioactivity_data_raw.csv (deflated 91%)
# updating: serotonin_02_bioactivity_data_preprocessed.csv (deflated 81%)
# updating: serotonin_03_bioactivity_data_curated.csv (deflated 82%)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls -l
# Out:
# total 3152
# drwx------ 5 root root    4096 Jan  7 13:46 drive
# drwxr-xr-x 1 root root    4096 Jan  5 14:34 sample_data
# -rw-r--r-- 1 root root 2299786 Jan  7 11:12 serotonin_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  195575 Jan  7 11:44 serotonin_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  220676 Jan  7 11:45 serotonin_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  499124 Jan  7 13:46 serotonin.zip

# %% [markdown]
# ---
